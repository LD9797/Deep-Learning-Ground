# %%
import torch

def evaluate_f(x):
    z = x[0] ** 2 - 0.2 * x[1] ** 2
    return z
    
def evaluate_grad_x(x_a):
    grad_x = torch.tensor([2 *x_a[0], -0.4*x_a[1] ])
    return grad_x




def evaluate_f_2(x):
    z = x[0] ** 2 +  x[1] ** 2
    return z
    
def evaluate_grad_x_2(x_a):
    grad_x = torch.tensor([2 *x_a[0], 2*x_a[1] ])
    return grad_x

def random_init_x():
    x_a = torch.tensor([-75, -50])
    return x_a
    
def update_x(x_t, evaluate_grad_x_n,  alpha = 0.1):
    #calculate the gradient in x_t
    grad_x = evaluate_grad_x_n(x_t)
    #update x, making x(t + 1)
    x_t_plus_1 = x_t - alpha * grad_x
    return x_t_plus_1

def update_x_adagrad(x_t, s_t, evaluate_grad_x_n,  rho = 1, iteration_frame = 5):
    #calculate the gradient in x_t
    grad_x = evaluate_grad_x_n(x_t)
    #update s(t)
    s_t = s_t + (grad_x) ** 2
    #print("s_t")
    #print(s_t)
    #alpha_t inverse of s_t (element wise)
    alpha_t = rho / s_t 
    #update x, making x(t + 1)
    x_t_plus_1 = x_t - alpha_t * grad_x
    return x_t_plus_1

def run_gradient_descent(evaluate_f, evaluate_grad_x_n, T = 30):
    x_0 = random_init_x()
    #repeat T times
    x_t = x_0
    print("Iteracion 0 ", x_t)
    for i in range(0, T):
        x_t = update_x(x_t, evaluate_grad_x_n)
        print("Iteracion ", i, " ",  x_t, "f(x_t): ", evaluate_f(x_t))
    return x_t    


def run_adaptive_gradient_descent(evaluate_f, evaluate_grad_x_n, T = 20):
    x_0 = random_init_x()
    #repeat T times
    x_t = x_0
    epsilon = 0.00001
    #init s_t
    s_t = torch.ones(2) * epsilon
    print("Iteracion 0 ", x_t)
    for i in range(0, T):
        x_t = update_x_adagrad(x_t, s_t, evaluate_grad_x_n)
        print("Iteracion ", i, " ",  x_t, "f(x_t): ", evaluate_f(x_t))
    return x_t    


def run_newton_rhapson(evaluate_grad_x_n, T = 20):
    x_0 = random_init_x()
    #repeat T times
    x_t = x_0
    epsilon = 0.00001
    #init s_t
    s_t = torch.ones(2) * epsilon
    print("Iteracion 0 ", x_t)
    for i in range(0, T):
        x_t = update_x_adagrad(x_t, s_t, evaluate_grad_x_n)
        print("Iteracion ", i, " ",  x_t, "f(x_t): ", evaluate_f(x_t))
    return x_t 
    
def test_1():    
    #unit test 1    
    x_a = torch.tensor([10.0, 0])
    x_b = update_x(x_a)
    print(x_b)

def test_2():
    run_gradient_descent(evaluate_f, evaluate_grad_x)
    
def test_3():
    run_adaptive_gradient_descent(evaluate_f, evaluate_grad_x)

def test_4():    
    run_gradient_descent(evaluate_f_2, evaluate_grad_x_2)

print("G.D on x[0] ** 2 + x[1] ** 2")
test_4()
# Out:
# G.D on x[0] ** 2 + x[1] ** 2
# Iteracion 0  tensor([-75, -50])
# Iteracion  0   tensor([-60., -40.]) f(x_t):  tensor(5200.)
# Iteracion  1   tensor([-48., -32.]) f(x_t):  tensor(3328.)
# Iteracion  2   tensor([-38.4000, -25.6000]) f(x_t):  tensor(2129.9202)
# Iteracion  3   tensor([-30.7200, -20.4800]) f(x_t):  tensor(1363.1488)
# Iteracion  4   tensor([-24.5760, -16.3840]) f(x_t):  tensor(872.4152)
# Iteracion  5   tensor([-19.6608, -13.1072]) f(x_t):  tensor(558.3458)
# Iteracion  6   tensor([-15.7286, -10.4858]) f(x_t):  tensor(357.3413)
# Iteracion  7   tensor([-12.5829,  -8.3886]) f(x_t):  tensor(228.6984)
# Iteracion  8   tensor([-10.0663,  -6.7109]) f(x_t):  tensor(146.3670)
# Iteracion  9   tensor([-8.0531, -5.3687]) f(x_t):  tensor(93.6749)
# Iteracion  10   tensor([-6.4425, -4.2950]) f(x_t):  tensor(59.9519)
# Iteracion  11   tensor([-5.1540, -3.4360]) f(x_t):  tensor(38.3692)
# Iteracion  12   tensor([-4.1232, -2.7488]) f(x_t):  tensor(24.5563)
# Iteracion  13   tensor([-3.2985, -2.1990]) f(x_t):  tensor(15.7160)
# Iteracion  14   tensor([-2.6388, -1.7592]) f(x_t):  tensor(10.0583)
# Iteracion  15   tensor([-2.1111, -1.4074]) f(x_t):  tensor(6.4373)
# Iteracion  16   tensor([-1.6889, -1.1259]) f(x_t):  tensor(4.1199)
# Iteracion  17   tensor([-1.3511, -0.9007]) f(x_t):  tensor(2.6367)
# Iteracion  18   tensor([-1.0809, -0.7206]) f(x_t):  tensor(1.6875)
# Iteracion  19   tensor([-0.8647, -0.5765]) f(x_t):  tensor(1.0800)
# Iteracion  20   tensor([-0.6918, -0.4612]) f(x_t):  tensor(0.6912)
# Iteracion  21   tensor([-0.5534, -0.3689]) f(x_t):  tensor(0.4424)
# Iteracion  22   tensor([-0.4427, -0.2951]) f(x_t):  tensor(0.2831)
# Iteracion  23   tensor([-0.3542, -0.2361]) f(x_t):  tensor(0.1812)
# Iteracion  24   tensor([-0.2833, -0.1889]) f(x_t):  tensor(0.1160)
# Iteracion  25   tensor([-0.2267, -0.1511]) f(x_t):  tensor(0.0742)
# Iteracion  26   tensor([-0.1813, -0.1209]) f(x_t):  tensor(0.0475)
# Iteracion  27   tensor([-0.1451, -0.0967]) f(x_t):  tensor(0.0304)
# Iteracion  28   tensor([-0.1161, -0.0774]) f(x_t):  tensor(0.0195)
# Iteracion  29   tensor([-0.0928, -0.0619]) f(x_t):  tensor(0.0125)
